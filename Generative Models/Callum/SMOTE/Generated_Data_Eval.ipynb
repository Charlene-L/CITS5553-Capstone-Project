# %%
# # # re upload files everytime run

# from google.colab import files

# uploaded = files.upload()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
X_train =pd.read_csv('./Data/Adasyn Large/X_train_adasyn.csv')
y_train =pd.read_csv('./Data/Adasyn Large/y_train_adasyn.csv')
X_test = pd.read_csv('./Data/Adasyn Large/X_test_adasyn.csv')
y_test = pd.read_csv('./Data/Adasyn Large/y_test_adasyn.csv')



# ## Normal
# X_train_norm = pd.read_csv('./Data/Normal/X_train.csv')
# y_train_norm = pd.read_csv('./Data/Normal/y_train.csv')
# X_test_norm = pd.read_csv('./Data/Normal/X_test.csv')
# y_test_norm = pd.read_csv('./Data/Normal/y_test.csv')

# ## SMOTE
# X_train_smote =pd.read_csv('./Data/Smote Large/X_train_smote.csv')
# y_train_smote =pd.read_csv('./Data/Smote Large/y_train_smote.csv')
# X_test_smote = pd.read_csv('./Data/Smote Large/X_test_smote.csv')
# y_test_smote = pd.read_csv('./Data/Smote Large/y_test_smote.csv')

# ## Oversampling
# X_train_over =pd.read_csv('./Data/Oversampling/X_train_over.csv')
# y_train_over =pd.read_csv('./Data/Oversampling/y_train_over.csv')
# X_test_over = pd.read_csv('./Data/Oversampling/X_test_over.csv')
# y_test_over = pd.read_csv('./Data/Oversampling/y_test_over.csv')

# ## ADASYN
# X_train_adasyn =pd.read_csv('./Data/Adasyn Large/X_train_adasyn.csv')
# y_train_adasyn =pd.read_csv('./Data/Adasyn Large/y_train_adasyn.csv')
# X_test_adasyn = pd.read_csv('./Data/Adasyn Large/X_test_adasyn.csv')
# y_test_adasyn = pd.read_csv('./Data/Adasyn Large/y_test_adasyn.csv')

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

frames_X = [X_train, X_test]
frames_y = [y_train, y_test]

X = pd.concat(frames_X)
y = pd.concat(frames_y)

#X = X.iloc[:,13:].copy() # select only features

print(X.shape)
print(y.shape)
# Out:
# (8169, 122)
# (8169, 2)
# (1442, 122)
# (1442, 2)
# (9611, 122)
# (9611, 2)

# %%
## Normal
X_train_norm = pd.read_csv('./Data/Normal/X_train.csv')
y_train_norm = pd.read_csv('./Data/Normal/y_train.csv')
X_test_norm = pd.read_csv('./Data/Normal/X_test.csv')
y_test_norm = pd.read_csv('./Data/Normal/y_test.csv')

## SMOTE
X_train_smote = pd.read_csv('./Data/Smote Large/X_train_smote.csv')
y_train_smote = pd.read_csv('./Data/Smote Large/y_train_smote.csv')
X_test_smote = pd.read_csv('./Data/Smote Large/X_test_smote.csv')
y_test_smote = pd.read_csv('./Data/Smote Large/y_test_smote.csv')

## Oversampling
X_train_over = pd.read_csv('./Data/Oversampling/X_train_over.csv')
y_train_over = pd.read_csv('./Data/Oversampling/y_train_over.csv')
X_test_over = pd.read_csv('./Data/Oversampling/X_test_over.csv')
y_test_over = pd.read_csv('./Data/Oversampling/y_test_over.csv')

## ADASYN
X_train_adasyn = pd.read_csv('./Data/Adasyn Large/X_train_adasyn.csv')
y_train_adasyn = pd.read_csv('./Data/Adasyn Large/y_train_adasyn.csv')
X_test_adasyn = pd.read_csv('./Data/Adasyn Large/X_test_adasyn.csv')
y_test_adasyn = pd.read_csv('./Data/Adasyn Large/y_test_adasyn.csv')

# %%
X['Id'] = np.arange(len(X))
X['OverallPoF'] = y['OverallPoF']
X_long = pd.melt(X[X['OverallPoF'] == 0], id_vars=['Id','OverallPoF'], value_vars=['f(226.0000)','f(257.3256)','f(280.6155)','f(297.3018)','f(324.2099)','f(343.4884)','f(363.9133)','f(385.5527)','f(408.4789)','f(432.7683)','f(458.5020)','f(471.9372)','f(500.0000)','f(514.6511)','f(545.2539)','f(561.2310)','f(577.6763)','f(594.6036)','f(629.9605)','f(648.4198)','f(667.4199)','f(686.9768)','f(707.1068)','f(727.8266)','f(749.1535)','f(771.1054)','f(793.7005)','f(816.9577)','f(840.8964)','f(865.5366)','f(890.8987)','f(917.0040)','f(943.8743)','f(971.5319)','f(1000.0000)','f(1029.3022)','f(1059.4631)','f(1090.5077)','f(1122.4620)','f(1155.3527)','f(1189.2071)','f(1224.0535)','f(1259.9210)','f(1296.8396)','f(1334.8399)','f(1373.9536)','f(1414.2136)','f(1455.6532)','f(1498.3071)','f(1542.2108)','f(1587.4011)','f(1633.9155)','f(1681.7928)','f(1731.0731)','f(1781.7974)','f(1834.0081)','f(1887.7486)','f(1943.0639)','f(2000.0000)','f(2058.6045)','f(2118.9262)','f(2181.0155)','f(2244.9241)','f(2310.7054)','f(2378.4142)','f(2448.1071)','f(2519.8421)','f(2593.6791)','f(2669.6797)','f(2747.9073)','f(2828.4271)','f(2911.3064)','f(2996.6142)','f(3084.4217)','f(3174.8021)','f(3267.8309)','f(3363.5857)','f(3462.1462)','f(3563.5949)','f(3668.0162)','f(3775.4973)','f(3886.1278)','f(4000.0000)','f(4117.2089)','f(4237.8524)','f(4362.0309)','f(4489.8482)','f(4621.4108)','f(4756.8285)','f(4896.2142)','f(5039.6842)','f(5187.3582)','f(5339.3594)','f(5495.8146)','f(5656.8542)','f(5822.6127)','f(5993.2283)','f(6168.8433)','f(6349.6042)','f(6535.6618)','f(6727.1713)','f(6924.2925)','f(7127.1897)','f(7336.0323)','f(7550.9945)','f(7772.2555)','f(8000.0000)'],var_name='Frequency', value_name='WBA')
#X_long['Frequency_str'] = X_long['Frequency']
#X_long['Frequency'] = X_long['Frequency'].str[2:-1].astype(float)

# %%
X_long['Id'].head()
# Out:
# 0     0
# 1     2
# 2     6
# 3     9
# 4    10
# Name: Id, dtype: int64

# %%
id = 2

fig, ax = plt.subplots()
ax.scatter(X_long["Frequency"], X_long["WBA"], alpha=0.1)
ax.scatter(X_long.loc[X_long['Id'] == id, "Frequency"], X_long.loc[X_long['Id'] == id, "WBA"])
ax.set_xlabel("Frequency")
ax.set_ylabel("WBA")
ax.set_title("ADASYN Generated Wideband Absorbance Data")
plt.show()

# %%
import seaborn as sns

sns.set(rc={'figure.figsize':(15,10)})

ax = sns.boxplot(x="Frequency", y="WBA", data=X_long)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")

ax.axes.set_title("SVMSMOTE Data", fontsize=20)
ax.set_xlabel("Frequency", fontsize=20)
ax.set_ylabel("Absorbance",fontsize=20)

ax.axhline(1.0, ls='--', color='grey')
ax.axhline(0.8, ls='--', color='grey')
ax.axhline(0.6, ls='--', color='grey')
ax.axhline(0.4, ls='--', color='grey')
ax.axhline(0.2, ls='--', color='grey')
ax.axhline(0.0, ls='--', color='grey')
ax.patch.set_facecolor('white')

sns.set(rc={'figure.figsize':(20,10)})
plt.setp(ax.get_xticklabels()[::2], visible=False)

plt.tight_layout()
plt.show();
