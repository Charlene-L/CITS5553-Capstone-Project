# %%
#Load the required libraries
import pandas as pd
import numpy as np
import seaborn as sns

#Load the data
df = pd.read_excel("/Users/lijiaze/Desktop/2022-2/CITS5553/EDA/WBAFinalMergedAbsorbanceAdmittancePhaseCMGReduced_1391295174.xlsx",sheet_name="Absorbance")


#View the data
df.head()
# Out:
#    Subject  Gender        DOT        DOB   AgeM      AgeY        Eth1 Eth2  \
# 0      8.0     0.0 2016-05-12 2006-12-18  112.0  9.333333  Australian  NaN
# 1     22.0     0.0 2016-05-18 2006-10-27  114.0  9.500000  Australian  NaN
# 2     24.0     1.0 2016-05-18 2006-07-02  118.0  9.833333  Australian  NaN
# 3     31.0     0.0 2016-05-19 2006-06-01  119.0  9.916667  Australian  NaN
# 4     42.0     0.0 2016-05-20 2008-06-03   95.0  7.916667  Australian  NaN
#
#    Unnamed: 15    Lang1  ... f(6168.8433)  f(6349.6042)  f(6535.6618)  \
# 0          0.0  English  ...       0.5370        0.4869        0.4301
# 1          0.0  English  ...       0.2636        0.2578        0.2443
# 2          0.0  English  ...       0.4269        0.4142        0.3910
# 3          0.0  English  ...       0.0077        0.0123        0.0066
# 4          0.0  English  ...       0.2332        0.2216        0.2228
#
#    f(6727.1713)  f(6924.2925)  f(7127.1897)  f(7336.0323)  f(7550.9945)  \
# ...

# %%
#Basic information

df.info()

#Describe the data

df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239 entries, 0 to 238
# Columns: 146 entries, Subject to f(8000.0000)
# dtypes: datetime64[ns](2), float64(136), object(8)
# memory usage: 272.7+ KB
#           Subject      Gender        AgeM        AgeY  Unnamed: 15  Lang3  \
# count  239.000000  239.000000  239.000000  239.000000   186.000000    0.0
# mean   247.652720    0.435146  106.426778    8.868898     0.204301    NaN
# std    137.757005    0.496817    8.507157    0.708930     0.404278    NaN
# min      8.000000    0.000000   93.000000    7.750000     0.000000    NaN
# 25%    119.500000    0.000000  100.000000    8.333333     0.000000    NaN
# 50%    230.000000    0.000000  104.000000    8.666667     0.000000    NaN
# 75%    369.500000    1.000000  114.000000    9.500000     0.000000    NaN
# max    496.000000    1.000000  129.000000   10.750000     1.000000    NaN
#
#        Unnamed: 19  PTA0.5   PTA1   PTA2  ...  f(6168.8433)  f(6349.6042)  \
# ...

# %%
# 按列进行拆分
attribute = df.loc[:,['Gender','AgeM','ECV','TPP','SC','TympType','TympPoF','OAE1','OAE1.4','OAE2','OAE2.8','OAE4','OAEPoFC','OverallPoF','Ear coded']]

frequency= df.iloc[:,39:]

# %%
#View the data
attribute.head()
# Out:
#    Gender   AgeM   ECV    TPP    SC TympType  TympPoF  OAE1  OAE1.4  OAE2  \
# 0     0.0  112.0  1.08 -189.0  0.52       C1      1.0   3.0    10.0  18.0
# 1     0.0  114.0  1.28  -49.0  1.28        A      0.0   7.0     4.0   9.0
# 2     1.0  118.0  1.26  -27.0  0.87        A      0.0   9.0    12.0   8.0
# 3     0.0  119.0  0.64   -8.0  0.60        A      0.0  13.0     9.0  13.0
# 4     0.0   95.0  0.92  -17.0  1.65        A      0.0   7.0     0.0   2.0
#
#    OAE2.8  OAE4  OAEPoFC  OverallPoF  Ear coded
# 0    14.0   8.0      0.0         1.0        0.0
# 1     5.0   6.0      0.0         0.0        0.0
# 2    12.0  16.0      0.0         0.0        0.0
# 3    11.0  12.0      0.0         0.0        0.0
# 4    12.0   6.0      1.0         1.0        0.0

# %%
#View the data
frequency.head()
# Out:
#    f(226.0000)  f(257.3256)  f(280.6155)  f(297.3018)  f(324.2099)  \
# 0       0.0987       0.1274       0.1592       0.1737       0.1700
# 1       0.1114       0.1501       0.1860       0.2033       0.1953
# 2       0.1096       0.1509       0.1941       0.2156       0.2139
# 3       0.0748       0.0953       0.1190       0.1285       0.1233
# 4       0.1863       0.2230       0.2641       0.2836       0.2794
#
#    f(343.4884)  f(363.9133)  f(385.5527)  f(408.4789)  f(432.7683)  ...  \
# 0       0.1617       0.1640       0.1799       0.1932       0.1969  ...
# 1       0.1831       0.1825       0.1934       0.2047       0.2090  ...
# 2       0.2065       0.2172       0.2413       0.2607       0.2706  ...
# 3       0.1151       0.1169       0.1294       0.1411       0.1465  ...
# 4       0.2685       0.2701       0.2846       0.3011       0.3072  ...
#
#    f(6168.8433)  f(6349.6042)  f(6535.6618)  f(6727.1713)  f(6924.2925)  \
# ...

# %% [markdown]
# ## Cleaning

# %%
attribute.head()
# Out:
#    Gender   AgeM   ECV    TPP    SC TympType  TympPoF  OAE1  OAE1.4  OAE2  \
# 0     0.0  112.0  1.08 -189.0  0.52       C1      1.0   3.0    10.0  18.0
# 1     0.0  114.0  1.28  -49.0  1.28        A      0.0   7.0     4.0   9.0
# 2     1.0  118.0  1.26  -27.0  0.87        A      0.0   9.0    12.0   8.0
# 3     0.0  119.0  0.64   -8.0  0.60        A      0.0  13.0     9.0  13.0
# 4     0.0   95.0  0.92  -17.0  1.65        A      0.0   7.0     0.0   2.0
#
#    OAE2.8  OAE4  OAEPoFC  OverallPoF  Ear coded
# 0    14.0   8.0      0.0         1.0        0.0
# 1     5.0   6.0      0.0         0.0        0.0
# 2    12.0  16.0      0.0         0.0        0.0
# 3    11.0  12.0      0.0         0.0        0.0
# 4    12.0   6.0      1.0         1.0        0.0

# %%
#Find the duplicates
df.duplicated().sum()
# Out:
# 0

# %%
attribute.duplicated().sum()
# Out:
# 0

# %%
frequency.duplicated().sum()
# Out:
# 2

# %%
#unique values

# df['Pclass'].unique()

# df['Survived'].unique()

# df['Sex'].unique()

# %%
#Find null values
attribute.isnull().sum()
# Out:
# Gender        0
# AgeM          0
# ECV           0
# TPP           3
# SC            3
# TympType      0
# TympPoF       0
# OAE1          0
# OAE1.4        0
# OAE2          0
# OAE2.8        0
# OAE4          0
# OAEPoFC       0
# OverallPoF    0
# Ear coded     0
# dtype: int64

# %%
frequency.isnull().sum()
# Out:
# f(226.0000)     0
# f(257.3256)     0
# f(280.6155)     0
# f(297.3018)     0
# f(324.2099)     0
#                ..
# f(7127.1897)    0
# f(7336.0323)    0
# f(7550.9945)    0
# f(7772.2555)    0
# f(8000.0000)    0
# Length: 107, dtype: int64

# %%
frequency.isnull().sum()
# Out:
# f(226.0000)     0
# f(257.3256)     0
# f(280.6155)     0
# f(297.3018)     0
# f(324.2099)     0
#                ..
# f(7127.1897)    0
# f(7336.0323)    0
# f(7550.9945)    0
# f(7772.2555)    0
# f(8000.0000)    0
# Length: 107, dtype: int64

# %%
df.dropna(how='any', axis=0, subset=['TPP', 'SC'], inplace=True)

# %%
df.shape
# Out:
# (236, 146)

# %%
# 按列进行拆分
attribute = df.loc[:,['Gender','AgeM','ECV','TPP','SC','TympType','TympPoF','OAE1','OAE1.4','OAE2','OAE2.8','OAE4','OAEPoFC','OverallPoF','Ear coded']]

frequency= df.iloc[:,39:]

# %%
attribute['TympType'].value_counts()
# Out:
# A     209
# C1     15
# C2     12
# Name: TympType, dtype: int64

# %%
TympType_class = {'A': 0, 'C1': 1, 'C2': 2}
attribute['TympType'] = attribute['TympType'].map(TympType_class)

# %%
#Find null values
attribute.isnull().sum()
# Out:
# Gender        0
# AgeM          0
# ECV           0
# TPP           0
# SC            0
# TympType      0
# TympPoF       0
# OAE1          0
# OAE1.4        0
# OAE2          0
# OAE2.8        0
# OAE4          0
# OAEPoFC       0
# OverallPoF    0
# Ear coded     0
# dtype: int64

# %%
#Correlation 

attribute.corr()
# Out:
#               Gender      AgeM       ECV       TPP        SC  TympType  \
# Gender      1.000000  0.158045 -0.233554  0.031766 -0.044294  0.017083
# AgeM        0.158045  1.000000  0.019095  0.011453  0.129163 -0.007165
# ECV        -0.233554  0.019095  1.000000  0.012970  0.219124 -0.029010
# TPP         0.031766  0.011453  0.012970  1.000000 -0.187235 -0.923581
# SC         -0.044294  0.129163  0.219124 -0.187235  1.000000  0.164864
# TympType    0.017083 -0.007165 -0.029010 -0.923581  0.164864  1.000000
# TympPoF     0.032642  0.002488 -0.062419 -0.877653  0.231343  0.939213
# OAE1        0.042542  0.135864 -0.122833  0.460598 -0.099822 -0.436364
# OAE1.4     -0.086094  0.151032 -0.019425  0.343194 -0.107626 -0.344402
# OAE2       -0.093306  0.169885 -0.032472  0.228412 -0.093998 -0.212115
# OAE2.8     -0.017918  0.004987 -0.087631  0.311328 -0.064729 -0.274862
# OAE4        0.061498  0.034894 -0.129235  0.227638 -0.047469 -0.211715
# ...

# %% [markdown]
# ### Visualization

# %%
#Correlation plot

sns.heatmap(attribute.corr())
# Out:
# <AxesSubplot:>

# %%
# %matplotlib inline
attribute.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'Gender'}>,
#         <AxesSubplot:title={'center':'AgeM'}>,
#         <AxesSubplot:title={'center':'ECV'}>,
#         <AxesSubplot:title={'center':'TPP'}>],
#        [<AxesSubplot:title={'center':'SC'}>,
#         <AxesSubplot:title={'center':'TympType'}>,
#         <AxesSubplot:title={'center':'TympPoF'}>,
#         <AxesSubplot:title={'center':'OAE1'}>],
#        [<AxesSubplot:title={'center':'OAE1.4'}>,
#         <AxesSubplot:title={'center':'OAE2'}>,
#         <AxesSubplot:title={'center':'OAE2.8'}>,
#         <AxesSubplot:title={'center':'OAE4'}>],
#        [<AxesSubplot:title={'center':'OAEPoFC'}>,
#         <AxesSubplot:title={'center':'OverallPoF'}>,
#         <AxesSubplot:title={'center':'Ear coded'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
frequency.iloc[:,1:2]
# Out:
#      f(257.3256)
# 0         0.1274
# 1         0.1501
# 2         0.1509
# 3         0.0953
# 4         0.2230
# ..           ...
# 234       0.0736
# 235       0.0738
# 236       0.1186
# 237       0.0414
# 238       0.0294
#
# [236 rows x 1 columns]

# %%
frequency.shape[0]
# Out:
# 236

# %%
a=frequency.values.tolist()
a[1]
# Out:
# [0.1114,
#  0.1501,
#  0.186,
#  0.2033,
#  0.1953,
#  0.1831,
#  0.1825,
#  0.1934,
#  0.2047,
#  0.209,
#  0.1976,
#  0.2039,
#  0.2328,
#  0.2685,
#  0.2881,
#  0.2945,
#  0.2897,
#  0.286,
#  0.2995,
#  0.3227,
#  0.3391,
#  0.3331,
#  0.3224,
#  0.3189,
#  0.3433,
#  0.3746,
#  0.3959,
#  0.3978,
#  0.4007,
#  0.4147,
#  0.4429,
#  0.4798,
#  0.4845,
#  0.4749,
#  0.4923,
#  0.5413,
#  0.5623,
#  0.5677,
#  0.5588,
#  0.5373,
#  0.4905,
#  0.473,
#  0.5123,
#  0.5723,
#  0.585,
#  0.5796,
#  0.5956,
#  0.6186,
#  0.6162,
#  0.6015,
#  0.6003,
#  0.6084,
#  0.5785,
#  0.506,
#  0.4805,
#  0.5129,
#  0.5498,
#  0.5264,
#  0.4878,
#  0.4813,
#  0.4627,
#  0.4807,
#  0.5316,
#  0.5089,
#  0.5539,
#  0.6224,
#  0.6327,
#  0.6382,
#  0.6299,
#  0.6271,
#  0.6319,
#  0.6045,
#  0.6462,
#  0.6485,
#  0.6693,
#  0.7022,
#  0.7422,
#  0.7781,
#  0.8128,
#  0.8389,
#  0.8544,
#  0.8376,
#  0.842,
#  0.8163,
#  0.7737,
#  0.7189,
#  0.6694,
#  0.5809,
#  0.4942,
#  0.4445,
#  0.4712,
# ...

# %%
xname=frequency.columns.to_list
print(xname)
# Out:
# <bound method IndexOpsMixin.tolist of Index(['f(226.0000)', 'f(257.3256)', 'f(280.6155)', 'f(297.3018)',
#        'f(324.2099)', 'f(343.4884)', 'f(363.9133)', 'f(385.5527)',
#        'f(408.4789)', 'f(432.7683)',
#        ...
#        'f(6168.8433)', 'f(6349.6042)', 'f(6535.6618)', 'f(6727.1713)',
#        'f(6924.2925)', 'f(7127.1897)', 'f(7336.0323)', 'f(7550.9945)',
#        'f(7772.2555)', 'f(8000.0000)'],
#       dtype='object', length=107)>

# %%
len(a)
# Out:
# 236

# %%
import matplotlib.pyplot as plt

# %%
y = a[1]
x = np.arange(len(y))
plt.plot(x,y) 
plt.show()

# %%
fig = plt.figure(figsize=(20,15))
t=np.arange(len(y))
ln=[]
for i in range(len(a)):
    y = a[i]
    ax=plt.plot(t,y)
    # pd.DataFrame({'data1': y},
    #          index=xname).plot.line()
# plt.axis(frequency.columns)

# %% [markdown]
# After data cleaning, I also did the traditional visual variables analysis and also specifically used each frequency as a horizontal coordinate to get the frequency absorption distribution for each Participant, (the graph is messy) and found that the peak of frequency absorption was around 3500 to 4000.

# %%
frequency.shape[1]
# Out:
# 107

# %% [markdown]
# ## random forest & PCA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.model_selection as ms
from sklearn.svm import SVR
from sklearn.model_selection  import train_test_split
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from pandas.plotting import scatter_matrix
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
attribute.head()
# Out:
#    Gender   AgeM   ECV    TPP    SC  TympType  TympPoF  OAE1  OAE1.4  OAE2  \
# 0     0.0  112.0  1.08 -189.0  0.52         1      1.0   3.0    10.0  18.0
# 1     0.0  114.0  1.28  -49.0  1.28         0      0.0   7.0     4.0   9.0
# 2     1.0  118.0  1.26  -27.0  0.87         0      0.0   9.0    12.0   8.0
# 3     0.0  119.0  0.64   -8.0  0.60         0      0.0  13.0     9.0  13.0
# 4     0.0   95.0  0.92  -17.0  1.65         0      0.0   7.0     0.0   2.0
#
#    OAE2.8  OAE4  OAEPoFC  OverallPoF  Ear coded
# 0    14.0   8.0      0.0         1.0        0.0
# 1     5.0   6.0      0.0         0.0        0.0
# 2    12.0  16.0      0.0         0.0        0.0
# 3    11.0  12.0      0.0         0.0        0.0
# 4    12.0   6.0      1.0         1.0        0.0

# %%
data = attribute[['Gender','AgeM','ECV','TPP','SC','TympPoF','OAE1','OAE1.4','OAE2','OAE2.8','OAE4','OAEPoFC','Ear coded']]
target = attribute['OverallPoF']

# %%
data.head()
# Out:
#    Gender   AgeM   ECV    TPP    SC  TympPoF  OAE1  OAE1.4  OAE2  OAE2.8  \
# 0     0.0  112.0  1.08 -189.0  0.52      1.0   3.0    10.0  18.0    14.0
# 1     0.0  114.0  1.28  -49.0  1.28      0.0   7.0     4.0   9.0     5.0
# 2     1.0  118.0  1.26  -27.0  0.87      0.0   9.0    12.0   8.0    12.0
# 3     0.0  119.0  0.64   -8.0  0.60      0.0  13.0     9.0  13.0    11.0
# 4     0.0   95.0  0.92  -17.0  1.65      0.0   7.0     0.0   2.0    12.0
#
#    OAE4  OAEPoFC  Ear coded
# 0   8.0      0.0        0.0
# 1   6.0      0.0        0.0
# 2  16.0      0.0        0.0
# 3  12.0      0.0        0.0
# 4   6.0      1.0        0.0

# %%
# Perform a random 85/15 split of the data to form a training set and a test set
X_train,X_test,y_train,y_test = ms.train_test_split(data,target,train_size=0.85, random_state=4)
print(len(X_train), "train +", len(X_test), "test")
print("X_train_shape:", X_train.shape, " y_train_shape:", y_train.shape)
print("X_test_shape:", X_test.shape,"  y_test_shape:", y_test.shape)
# Out:
# 200 train + 36 test
# X_train_shape: (200, 13)  y_train_shape: (200,)
# X_test_shape: (36, 13)   y_test_shape: (36,)

# %%
from sklearn.model_selection  import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
def regressor(regressor_name,param):
    # Parameters are tuned with GridSearchCV.
    clf = GridSearchCV(regressor_name(n_estimators=500,max_samples=0.7, bootstrap=True),param_grid=param,cv=3)
    clf.fit(X_train, y_train)#Train the regressor with the training set
    return clf.best_params_,clf.best_score_ #To get the best result of parameter

# %%
rf = RandomForestRegressor(n_estimators=500,max_samples=0.7, bootstrap=True,min_samples_leaf=2,max_features=5,random_state=42)
rf.fit(X_train, y_train)
score = 100 * rf.score(X_train, y_train)
print('Accuracy:', round(score, 2), '%.')
# Out:
# Accuracy: 97.79 %.

# %%
y_train_true,y_train_pred=y_train,rf.predict(X_train)

# %%
y_train_pred
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 9.92166667e-01,
#        9.78500000e-01, 2.43333333e-02, 1.00000000e-03, 0.00000000e+00,
#        3.00000000e-03, 2.72666667e-02, 2.55666667e-02, 9.69333333e-01,
#        0.00000000e+00, 2.33333333e-02, 2.21666667e-02, 0.00000000e+00,
#        0.00000000e+00, 2.50000000e-03, 0.00000000e+00, 3.00000000e-03,
#        3.33333333e-03, 0.00000000e+00, 3.50000000e-03, 9.56933333e-01,
#        0.00000000e+00, 5.33333333e-03, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.33333333e-03, 1.00000000e-03, 3.60000000e-03,
#        6.66666667e-04, 1.43333333e-02, 9.87333333e-01, 0.00000000e+00,
#        1.00000000e-03, 9.88300000e-01, 1.33333333e-03, 4.38666667e-02,
#        7.86666667e-03, 3.33333333e-03, 0.00000000e+00, 1.20000000e-02,
#        5.16666667e-03, 1.00000000e-03, 2.00000000e-03, 7.87200000e-01,
#        4.00000000e-03, 3.00000000e-03, 1.03333333e-02, 9.70700000e-01,
# ...

# %%
y_train_pred
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 9.92166667e-01,
#        9.78500000e-01, 2.43333333e-02, 1.00000000e-03, 0.00000000e+00,
#        3.00000000e-03, 2.72666667e-02, 2.55666667e-02, 9.69333333e-01,
#        0.00000000e+00, 2.33333333e-02, 2.21666667e-02, 0.00000000e+00,
#        0.00000000e+00, 2.50000000e-03, 0.00000000e+00, 3.00000000e-03,
#        3.33333333e-03, 0.00000000e+00, 3.50000000e-03, 9.56933333e-01,
#        0.00000000e+00, 5.33333333e-03, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.33333333e-03, 1.00000000e-03, 3.60000000e-03,
#        6.66666667e-04, 1.43333333e-02, 9.87333333e-01, 0.00000000e+00,
#        1.00000000e-03, 9.88300000e-01, 1.33333333e-03, 4.38666667e-02,
#        7.86666667e-03, 3.33333333e-03, 0.00000000e+00, 1.20000000e-02,
#        5.16666667e-03, 1.00000000e-03, 2.00000000e-03, 7.87200000e-01,
#        4.00000000e-03, 3.00000000e-03, 1.03333333e-02, 9.70700000e-01,
# ...

# %%
# Calculate the Root Mean Square Error(RMSE)
rmse = sqrt(mean_squared_error(y_train_true,y_train_pred))
# Print out the RMSE
print ("RMSE for train data set:", rmse)
# Out:
# RMSE for train data set: 0.05308201950231777

# %%
# the RMSE of the predictions on the test sets
y_test_true, y_test_pred = y_test, rf.predict(X_test)
# the quality wine values must be integers
y_test_pred = np.round(y_test_pred)
# Calculate the Root Mean Square Error(RMSE)
rmse_test = sqrt(mean_squared_error(y_test_true, y_test_pred))
# Print out the RMSE
print("RMSE for test data set:", rmse_test)
# Out:
# RMSE for test data set: 0.0

# %%
# feature importance
importances = rf.feature_importances_
feat_labels = ['Gender','AgeM','ECV','TPP','SC','TympPoF','OAE1','OAE1.4','OAE2','OAE2.8','OAE4','OAEPoFC','Ear coded']
indices = np.argsort(importances)[::-1]
for f in range(X_train.shape[1]):
    print("%2d) %-*s %f" % (f + 1, 30, feat_labels[indices[f]], importances[indices[f]]))
# Out:
#  1) TympPoF                        0.331326
#  2) TPP                            0.284901
#  3) OAEPoFC                        0.184568
#  4) OAE2                           0.056260
#  5) OAE1.4                         0.049346
#  6) OAE1                           0.047392
#  7) OAE4                           0.020439
#  8) OAE2.8                         0.014369
#  9) SC                             0.004103
# 10) ECV                            0.003679
# 11) AgeM                           0.002428
# 12) Ear coded                      0.000939
# 13) Gender                         0.000251

# %% [markdown]
# Only those features whose importance is higher than 5% are retained

# %% [markdown]
# Finally PCA and Random Forest algorithms were used to classify the dataset, look at the relative importance of the model input features, perform data dimensionality reduction and the results showed that TympType , TPP , OAE were relatively more important.

# %%
from sklearn.feature_selection import SelectFromModel
new_rf = SelectFromModel(rf, threshold=0.05)
X_train_new = new_rf.fit_transform(X_train, y_train)   
X_train_new.shape
# Out:
# (200, 4)

# %% [markdown]
# ## TSNE

# %%
# !pip install swat
# Out:
# ...
#      |████████████████████████████████| 457 kB 3.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 140 kB 10.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 62 kB 4.7 MB/s  eta 0:00:01
# ...
#   Using cached idna-3.3-py3-none-any.whl (61 kB)
# ...

# %%
# Load Python libraries
import swat
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from time import time

# %%
from __future__ import print_function
import time
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
time_start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity=40, n_iter=300)
tsne_results = tsne.fit_transform(frequency)
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 236 samples in 0.001s...
# [t-SNE] Computed neighbors for 236 samples in 0.008s...
# [t-SNE] Computed conditional probabilities for sample 236 / 236
# [t-SNE] Mean sigma: 0.695402
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 60.084641
# [t-SNE] KL divergence after 300 iterations: 0.836705

# %%
# For reproducability of the results
np.random.seed(42)
rndperm = np.random.permutation(df.shape[0])

# %%
# attribute['OverallPoF']=list(attribute['OverallPoF'])
frequency['OverallPoF']=list(attribute['OverallPoF'])

# %%
attribute['tsne-2d-one']
# Out:
# 0     -0.468997
# 1      2.957190
# 2      5.631432
# 3      8.158509
# 4      9.283949
#          ...
# 234   -0.023623
# 235    0.270101
# 236   -5.054406
# 237    2.763317
# 238    0.546111
# Name: tsne-2d-one, Length: 236, dtype: float32

# %%
attribute['tsne-2d-one'] = tsne_results[:,0]
attribute['tsne-2d-two'] = tsne_results[:,1]
plt.figure(figsize=(16,10))
sns.scatterplot(
    x="tsne-2d-one", y="tsne-2d-two",hue="OverallPoF",
    palette='hls',
    data=df,
    legend="full",
    alpha=0.5
)
plt.title('t-SNE of WBA')

# plt.savefig('deposittsne.pdf')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/lijiaze/Desktop/2022-2/CITS5553/EDA/WBA-EDA.ipynb Cell 56' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/lijiaze/Desktop/2022-2/CITS5553/EDA/WBA-EDA.ipynb#Y101sZmlsZQ%3D%3D?line=1'>2</a> attribute['tsne-2d-two'] = tsne_results[:,1]
#       <a href='vscode-notebook-cell:/Users/lijiaze/Desktop/2022-2/CITS5553/EDA/WBA-EDA.ipynb#Y101sZmlsZQ%3D%3D?line=2'>3</a> plt.figure(figsize=(16,10))
# ----> <a href='vscode-notebook-cell:/Users/lijiaze/Desktop/2022-2/CITS5553/EDA/WBA-EDA.ipynb#Y101sZmlsZQ%3D%3D?line=3'>4</a> sns.scatterplot(
#       <a href='vscode-notebook-cell:/Users/lijiaze/Desktop/2022-2/CITS5553/EDA/WBA-EDA.ipynb#Y101sZmlsZQ%3D%3D?line=4'>5</a>     x="tsne-2d-one", y="tsne-2d-two",hue="OverallPoF",
# ...
